-- %%
select szoba_fk, year(mettol),  
CASE  grouping(szoba_fk) WHEN 0 THEN CAST(YEAR(SZOBA_FK) AS nvarchar(4)) 
WHEN 1 THEN 'Összesen' END,
 count(*)
from foglalas
group by rollup ( szoba_fk, year(mettol))
-- Out:
-- (513 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %%
select f.*
from foglalas f join Vendeg v on f.ugyfel_fk=v.USERNEV
where SZUL_DAT= 
(select max(SZUL_DAT)
from vendeg
where SZUL_DAT < (
    select max(SZUL_DAT)
    from  vendeg)
)
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>FOGLALAS_PK</th><th>UGYFEL_FK</th><th>SZOBA_FK</th><th>METTOL</th><th>MEDDIG</th><th>FELNOTT_SZAM</th><th>GYERMEK_SZAM</th></tr><tr><td>583</td><td>istvan1</td><td>79</td><td>2016-04-16</td><td>2016-04-22</td><td>3</td><td>0</td></tr><tr><td>599</td><td>istvan1</td><td>162</td><td>2016-04-24</td><td>2016-04-28</td><td>3</td><td>0</td></tr><tr><td>689</td><td>istvan1</td><td>102</td><td>2016-07-19</td><td>2016-07-24</td><td>1</td><td>0</td></tr><tr><td>1507</td><td>istvan1</td><td>153</td><td>2017-02-07</td><td>2017-02-10</td><td>2</td><td>1</td></tr></table>

-- %% [markdown]
-- ![](data:image/png;base64,...)
